# %% [markdown]
# # Environment setup

# %% [markdown]
# ## Install Pandas
# That error means conda isn't installed on your system yet. Here's how to get it set up:
#
# 1. Download Miniconda (lightweight conda installer):
#    ```bash
#    # For macOS (Apple Silicon / M-series)
#    curl -O https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh
#
#    # For macOS (Intel)
#    curl -O https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-x86_64.sh
#    ```
#
# 2. Run the installer:
#    ```bash
#    bash Miniconda3-latest-MacOSX-arm64.sh
#    ```
#    Follow the prompts — say "yes" to the license and "yes" when it asks to initialize conda.
#
# 3. Reload your shell:
#    ```bash
#    source ~/.zshrc
#    ```
#
# 4. Verify it works:
#    ```bash
#    conda --version
#    ```
# 5. Now run your original command:
#    ```bash
#    conda install -c conda-forge pandas
#    ```

# %% [markdown]
# ## Create environment
#    ```bash
#    # Create an environment for your project
#    conda create -n myproject python=3.12
#
#    # Activate it
#    conda activate myproject
#
#    # Now install packages into that environment
#    conda install -c conda-forge pandas
#    ```
#
#    ```bash
#    conda activate myproject
#    conda install ipykernel
#    python -m ipykernel install --user --name myproject --display-name "myproject"
#    ```
#
# After creating and activating your conda environment, you need to make it visible as a kernel in VS Code:
#
# 1. Install the kernel package in your environment:
#    ```bash
#    conda activate myproject
#    conda install ipykernel
#    ```
#
# 2. Register it as a kernel:
#    ```bash
#    python -m ipykernel install --user --name myproject --display-name "myproject"
#    ```
#
# 3. In VS Code, open your notebook, click the kernel picker (top right), and you should see "myproject" in the list. If it doesn't appear immediately, reload the window (Cmd+Shift+P → "Reload Window").
#
# That's it — each conda environment you want to use in notebooks needs ipykernel installed and registered. The --display-name is what shows up in the picker.

# %% [markdown]
# ## Graphs
#
# ### Install Matplotlib
#    ```bash
#    conda install matplotlib
#    ```
#
# ### Install plotly
# ```bash
# conda activate myproject
# conda install -c conda-forge plotly
# ````
#
# If you also want static image export (PNG/PDF) from plotly:
#
# ```bash
# conda install -c conda-forge kaleido
# conda install -c conda-forge pillow
# conda install -c conda-forge nbformat
# ```

# %% [markdown]
# PackagesNotFoundInChannelsError: The following packages are not available from current channels:
#
#   - kaleido

# %% [markdown]
# Use pip for this one — kaleido's conda package can be spotty:
# Not everything is on conda-forge. When conda install fails to find a package, pip install inside the active environment is the fallback. Just try conda first as a habit.
#
# ```bash
# conda activate myproject
# pip install kaleido
# ```

# %% [markdown]
# ## Instal ipywiddgets
# ```bash
# conda activate myproject
# conda install -c conda-forge ipympl ipywidgets
# ```

# %% [markdown]
# ## Install fffmpeg
# ```bash
# conda activate myproject
# conda install -c conda-forge ffmpeg
# ````

# %% [markdown]
# Install

# %% [markdown]
# # Install Anaconda on Windows
#
# Copying the environment folder manually won't work — conda environments have hardcoded paths baked into them. You need to recreate it.
#
# On the old machine (if you still have access), export the environment:
#
# The environment.yml was exported from your Mac — all those packages are Mac-specific builds. Skip it and create fresh:
#
# conda create -n nomades-project python=3.12
# conda activate nomades-project
# conda install -c conda-forge pandas matplotlib plotly ipykernel ipympl ipywidgets nbformat pillow
# pip install kaleido
#
# Then register the kernel for VS Code:
#
# python -m ipykernel install --user --name nomades-project --display-name "nomades-project"
#
# To avoid this next time, export a cross-platform version on your Mac:
#
# --from-history only lists the packages you explicitly installed (not platform-specific dependencies), so it works across Mac/Windows/Linux.

# %% [markdown]
# # Video
#
# ```bash
# conda activate myproject
# conda install -c conda-forge ffmpeg-python
# ```
#
# Step 3 — Custom playback controls
#
# We'll use OpenCV to grab individual frames and display them with a slider.
#
# ```bash
# conda activate myproject
# conda install -c conda-forge opencv
# ```
