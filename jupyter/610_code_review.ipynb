# %% [markdown]
# #

# %% [markdown]
# ## session states
#
# ## loaded_data
# **sidebar:** pull data from the example files unless some data has been loaded via the sidebar
#
# **firestore:** game_data is always live Firestore data (get_game_data_dict_from_dict(raw_data)) — it never falls back to DEFAULTS["game_data"]. The example JSON is only ever used there as a fallback for buildings_df/map_image_path, not for game data.
# video_path on that page has no DEFAULTS fallback at all
